# %%
# from model import *
from utils import getImage

# # Path to the checkpoint file
# checkpoint_path = r'lightning_logs\medium_training\version_0\epoch=13-val_loss=0.77.ckpt'

# # Load the model from the checkpoint
# model = MLP.load_from_checkpoint(checkpoint_path)
# print(model)

# sample = getImage(debug=True, kappa=0)

# NOTE: aumentare i valori di focal_length e sensor_size rende meno problematica la presenza di kappa, anche se rimangono artefatti nella world_grid
sample = getImage(focal_length=0.036, sensor_size=(0.0367, 0.0274), debug=True, kappa=0.4)
# Out:
# world_scale_factor:  1.32
# 3d_center:  [0.33774116773262364, -8.025962104997202, 0, 1]
# zc:  [-0.07861604 -0.90841827 -0.41060414]
# b_hat:  [-0.03152428 -0.97743466 -0.20887245]
# image_box:  [[184.81309328 120.15688546]
#  [169.19469104 150.43326252]
#  [165.02822258  82.93572087]
#  [182.11564368  63.9690332 ]
#  [381.93784492 114.485266  ]
#  [405.22560699 143.40576373]
#  [407.55765412  76.71352013]
#  [383.17465238  58.77060873]]
# image_center:  [[285.38484815 129.39773319]]
# samples_counter:  4
